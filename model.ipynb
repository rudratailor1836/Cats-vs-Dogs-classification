# %%
import tensorflow as tf
from tensorflow import keras 
from keras.models import Sequential 
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten

# %%
# generrators to give data to model in batch as data is too big to fit in the RAM
train_ds = keras.utils.image_dataset_from_directory(
    directory='D:/Cats-vs-Dogs-classification/train',
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(256,256)
)
# Out:
# Found 25000 files belonging to 2 classes.

# %%
validation_ds = keras.utils.image_dataset_from_directory(directory='D:/Cats-vs-Dogs-classification/test_data',labels='inferred',label_mode='int',batch_size=32,image_size=(256,256))
# Out:
# Found 0 files belonging to 0 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 validation_ds = keras.utils.image_dataset_from_directory(directory='D:/Cats-vs-Dogs-classification/test_data',labels='inferred',label_mode='int',batch_size=32,image_size=(256,256))
#
# File c:\Users\rudra\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\image_dataset_utils.py:372, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     368 image_paths, labels = dataset_utils.get_training_or_validation_split(
#     369     image_paths, labels, validation_split, subset
#     370 )
#     371 if not image_paths:
# ...
